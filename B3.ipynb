# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/Churn_Modelling.csv')

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Gender'].replace(['Male', 'Female'],[1, 0], inplace= True)
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
df['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
X=df.drop(['Exited'],axis=1)
y=df['Exited']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.10,random_state=5)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=0.10,random_state=5)
print("X_train size is {}".format(X_train.shape[0]))
print("X_val size is {}".format(X_val.shape[0]))
print("X_test size is {}".format(X_test.shape[0]))
# Out:
# X_train size is 8100
# X_val size is 900
# X_test size is 1000

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
num_cols=['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']
num_subset=scaler.fit_transform(X_train[num_cols])
X_train_num_df=pd.DataFrame(num_subset,columns=num_cols)
X_train_num_df['Geography']=list(X_train['Geography'])
X_train_num_df['Gender']=list(X_train['Gender'])
X_train_num_df['HasCrCard']=list(X_train['HasCrCard'])
X_train_num_df['IsActiveMember']=list(X_train['IsActiveMember'])
X_train_num_df.head()
## Standardise the Validation data
num_subset=scaler.fit_transform(X_val[num_cols])
X_val_num_df=pd.DataFrame(num_subset,columns=num_cols)
X_val_num_df['Geography']=list(X_val['Geography'])
X_val_num_df['Gender']=list(X_val['Gender'])
X_val_num_df['HasCrCard']=list(X_val['HasCrCard'])
X_val_num_df['IsActiveMember']=list(X_val['IsActiveMember'])
## Standardise the Test data
num_subset=scaler.fit_transform(X_test[num_cols])
X_test_num_df=pd.DataFrame(num_subset,columns=num_cols)
X_test_num_df['Geography']=list(X_test['Geography'])
X_test_num_df['Gender']=list(X_test['Gender'])
X_test_num_df['HasCrCard']=list(X_test['HasCrCard'])
X_test_num_df['IsActiveMember']=list(X_test['IsActiveMember'])

# %%
## Convert the categorical features to numerical
X_train_num_df=pd.get_dummies(X_train_num_df,columns=['Geography','Gender'])
X_test_num_df=pd.get_dummies(X_test_num_df,columns=['Geography','Gender'])
X_val_num_df=pd.get_dummies(X_val_num_df,columns=['Geography','Gender'])
X_train_num_df.head()
# Out:
#    CreditScore       Age    Tenure   Balance  NumOfProducts  EstimatedSalary  \
# 0    -1.178587 -1.041960 -1.732257  0.198686       0.820905         1.560315
# 1    -0.380169 -1.326982  1.730718 -0.022020      -0.907991        -0.713592
# 2    -0.349062  1.808258 -0.693364  0.681178       0.820905        -1.126515
# 3     0.625629  2.378302 -0.347067 -1.229191       0.820905        -1.682740
# 4    -0.203895 -1.136967  1.730718  0.924256      -0.907991         1.332535
#
#    HasCrCard  IsActiveMember  Geography_France  Geography_Germany  \
# 0          1               1                 1                  0
# 1          1               0                 0                  0
# 2          1               0                 0                  1
# 3          1               1                 1                  0
# 4          1               1                 0                  0
#
#    Geography_Spain  Gender_0  Gender_1
# 0                0         0         1
# 1                1         1         0
# 2                0         1         0
# 3                0         0         1
# 4                1         0         1

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()
model.add(Dense(7,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
import tensorflow as tf
optimizer=tf.keras.optimizers.Adam(0.01)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
model.fit(X_train_num_df,y_train,epochs=100,batch_size=10,verbose=1)
# Out:
# Epoch 1/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3863 - accuracy: 0.8347
# Epoch 2/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3489 - accuracy: 0.8578
# Epoch 3/100
# 810/810 [==============================] - 2s 3ms/step - loss: 0.3477 - accuracy: 0.8553
# Epoch 4/100
# 810/810 [==============================] - 3s 3ms/step - loss: 0.3413 - accuracy: 0.8594
# Epoch 5/100
# 810/810 [==============================] - 2s 3ms/step - loss: 0.3425 - accuracy: 0.8610
# Epoch 6/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3391 - accuracy: 0.8626
# Epoch 7/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3382 - accuracy: 0.8637
# Epoch 8/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3379 - accuracy: 0.8636
# Epoch 9/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3378 - accuracy: 0.8623
# Epoch 10/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3349 - accuracy: 0.8651
# Epoch 11/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3349 - accuracy: 0.8640
# Epoch 12/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3357 - accuracy: 0.8614
# Epoch 13/100
# 810/810 [==============================] - 4s 5ms/step - loss: 0.3335 - accuracy: 0.8637
# Epoch 14/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3314 - accuracy: 0.8640
# Epoch 15/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3325 - accuracy: 0.8652
# Epoch 16/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3326 - accuracy: 0.8647
# Epoch 17/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3321 - accuracy: 0.8654
# Epoch 18/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3320 - accuracy: 0.8635
# Epoch 19/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3309 - accuracy: 0.8640
# Epoch 20/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3313 - accuracy: 0.8646
# Epoch 21/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3298 - accuracy: 0.8642
# Epoch 22/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3312 - accuracy: 0.8670
# Epoch 23/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3326 - accuracy: 0.8644
# Epoch 24/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3297 - accuracy: 0.8644
# Epoch 25/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3303 - accuracy: 0.8652
# Epoch 26/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3295 - accuracy: 0.8610
# Epoch 27/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3275 - accuracy: 0.8637
# Epoch 28/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3300 - accuracy: 0.8637
# Epoch 29/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3292 - accuracy: 0.8670
# Epoch 30/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3300 - accuracy: 0.8653
# Epoch 31/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3287 - accuracy: 0.8638
# Epoch 32/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3300 - accuracy: 0.8652
# Epoch 33/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3284 - accuracy: 0.8657
# Epoch 34/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3288 - accuracy: 0.8652
# Epoch 35/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3274 - accuracy: 0.8660
# Epoch 36/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3302 - accuracy: 0.8637
# Epoch 37/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3278 - accuracy: 0.8654
# Epoch 38/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3287 - accuracy: 0.8657
# Epoch 39/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3277 - accuracy: 0.8653
# Epoch 40/100
# 810/810 [==============================] - 2s 3ms/step - loss: 0.3287 - accuracy: 0.8644
# Epoch 41/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3280 - accuracy: 0.8653
# Epoch 42/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3267 - accuracy: 0.8648
# Epoch 43/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3261 - accuracy: 0.8674
# Epoch 44/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3271 - accuracy: 0.8672
# Epoch 45/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3287 - accuracy: 0.8651
# Epoch 46/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3278 - accuracy: 0.8659
# Epoch 47/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3269 - accuracy: 0.8641
# Epoch 48/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3284 - accuracy: 0.8665
# Epoch 49/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3276 - accuracy: 0.8663
# Epoch 50/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3276 - accuracy: 0.8658
# Epoch 51/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3267 - accuracy: 0.8685
# Epoch 52/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3276 - accuracy: 0.8660
# Epoch 53/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3283 - accuracy: 0.8668
# Epoch 54/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3270 - accuracy: 0.8664
# Epoch 55/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3262 - accuracy: 0.8668
# Epoch 56/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3289 - accuracy: 0.8633
# Epoch 57/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3284 - accuracy: 0.8670
# Epoch 58/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3271 - accuracy: 0.8669
# Epoch 59/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3278 - accuracy: 0.8678
# Epoch 60/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3275 - accuracy: 0.8656
# Epoch 61/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3280 - accuracy: 0.8664
# Epoch 62/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3265 - accuracy: 0.8649
# Epoch 63/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3252 - accuracy: 0.8670
# Epoch 64/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3273 - accuracy: 0.8660
# Epoch 65/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3256 - accuracy: 0.8674
# Epoch 66/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3262 - accuracy: 0.8667
# Epoch 67/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3271 - accuracy: 0.8673
# Epoch 68/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3273 - accuracy: 0.8644
# Epoch 69/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3273 - accuracy: 0.8644
# Epoch 70/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3268 - accuracy: 0.8637
# Epoch 71/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3270 - accuracy: 0.8642
# Epoch 72/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3261 - accuracy: 0.8673
# Epoch 73/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3264 - accuracy: 0.8663
# Epoch 74/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3262 - accuracy: 0.8654
# Epoch 75/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3273 - accuracy: 0.8637
# Epoch 76/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3269 - accuracy: 0.8665
# Epoch 77/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3277 - accuracy: 0.8656
# Epoch 78/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3264 - accuracy: 0.8674
# Epoch 79/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3252 - accuracy: 0.8669
# Epoch 80/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3262 - accuracy: 0.8652
# Epoch 81/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3256 - accuracy: 0.8641
# Epoch 82/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3260 - accuracy: 0.8656
# Epoch 83/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3261 - accuracy: 0.8678
# Epoch 84/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3271 - accuracy: 0.8681
# Epoch 85/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3240 - accuracy: 0.8680
# Epoch 86/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3276 - accuracy: 0.8652
# Epoch 87/100
# 810/810 [==============================] - 2s 3ms/step - loss: 0.3249 - accuracy: 0.8669
# Epoch 88/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3235 - accuracy: 0.8653
# Epoch 89/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3256 - accuracy: 0.8668
# Epoch 90/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3260 - accuracy: 0.8654
# Epoch 91/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3255 - accuracy: 0.8667
# Epoch 92/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3253 - accuracy: 0.8674
# Epoch 93/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3257 - accuracy: 0.8683
# Epoch 94/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3255 - accuracy: 0.8667
# Epoch 95/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3245 - accuracy: 0.8680
# Epoch 96/100
# 810/810 [==============================] - 2s 3ms/step - loss: 0.3253 - accuracy: 0.8665
# Epoch 97/100
# 810/810 [==============================] - 2s 2ms/step - loss: 0.3262 - accuracy: 0.8665
# Epoch 98/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3243 - accuracy: 0.8652
# Epoch 99/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3249 - accuracy: 0.8674
# Epoch 100/100
# 810/810 [==============================] - 1s 2ms/step - loss: 0.3259 - accuracy: 0.8674

# %%
y_pred_val=model.predict(X_val_num_df)
y_pred_val[y_pred_val>0.5]=1
y_pred_val[y_pred_val <0.5]=0
# Out:
# 29/29 [==============================] - 0s 1ms/step

# %%
y_pred_val=y_pred_val.tolist()
X_compare_val=X_val.copy()
X_compare_val['y_actual']=y_val
X_compare_val['y_pred']=y_pred_val
X_compare_val.head(10)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 340         341    15745844        Kerr          642   Germany       0   40
# 8622       8623    15747772  Cunningham          706   Germany       1   36
# 8401       8402    15663134  Uspenskaya          535     Spain       1   58
# 4338       4339    15798439    Davidson          714     Spain       1   25
# 8915       8916    15804962      Nnaife          606    France       1   36
# 2624       2625    15788946     Anthony          605     Spain       0   29
# 2234       2235    15713655   Calabrese          720    France       0   38
# 349         350    15576256    Yusupova          582    France       1   39
# 3719       3720    15577999     Sleeman          850    France       0   62
# 2171       2172    15747174         Hao          526   Germany       1   58
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 340        6  129502.49              2          0               1
# 8622       9   58571.18              2          1               0
# 8401       1       0.00              2          1               1
# 4338       2       0.00              1          1               1
# 8915       1  155655.46              1          1               1
# 2624       3  116805.82              1          0               0
# 2234      10       0.00              2          1               1
# 349        5       0.00              2          1               1
# 3719       1  124678.35              1          1               0
# 2171       9  190298.89              2          1               1
#
#       EstimatedSalary  y_actual y_pred
# 340          86099.23         1  [0.0]
# 8622         40774.01         0  [0.0]
# 8401         11779.98         1  [0.0]
# 4338        132979.43         0  [0.0]
# 8915        192387.51         1  [0.0]
# 2624          4092.75         0  [0.0]
# 2234         56229.72         1  [0.0]
# 349         129892.93         0  [0.0]
# 3719         70916.00         1  [1.0]
# 2171        191263.76         0  [0.0]

# %%
from sklearn.metrics import confusion_matrix
cm_val=confusion_matrix(y_val,y_pred_val)
cm_val
# Out:
# array([[689,  27],
#        [101,  83]])
